# %% [markdown]
# <a href="https://colab.research.google.com/github/arsingla786/MLFromScratch/blob/main/7label_encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib
# Out:
# Using matplotlib backend: <object object at 0x7a452cf330a0>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rajneesh231/retail-insights-a-comprehensive-sales-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/rajneesh231/retail-insights-a-comprehensive-sales-dataset/3.archive...
# 100%|██████████| 951k/951k [00:00<00:00, 99.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/rajneesh231/retail-insights-a-comprehensive-sales-dataset/versions/3

# %%
df = pd.read_csv('/root/.cache/kagglehub/datasets/rajneesh231/retail-insights-a-comprehensive-sales-dataset/versions/3/data.csv')

# %%
df.columns
# Out:
# Index(['Order No', 'Order Date', 'Customer Name', 'Address', 'City', 'State',
#        'Customer Type', 'Account Manager', 'Order Priority', 'Product Name',
#        'Product Category', 'Product Container', 'Ship Mode', 'Ship Date',
#        'Cost Price', 'Retail Price', 'Profit Margin', 'Order Quantity',
#        'Sub Total', 'Discount %', 'Discount $', 'Order Total', 'Shipping Cost',
#        'Total'],
#       dtype='object')

# %%
df.head()
# Out:
#   Order No  Order Date           Customer Name  \
# 0   4293-1  02-09-2014        Vivek Sundaresam
# 1   5001-1  24-10-2015          Shahid Hopkins
# 2   5004-1  13-03-2014           Dennis Pardue
# 3   5009-1  18-02-2013              Sean Wendt
# 4   5010-1  13-09-2014  Christina Vanderzanden
#
#                           Address       City State   Customer Type  \
# 0  152 Bunnerong Road,Eastgardens     Sydney   NSW  Small Business
# 1   438 Victoria Avenue,Chatswood     Sydney   NSW       Corporate
# 2        412 Brunswick St,Fitzroy  Melbourne   VIC        Consumer
# 3        145 Ramsay St,Haberfield     Sydney   NSW  Small Business
# 4          188 Pitt Street,Sydney     Sydney   NSW  Small Business
#
#   Account Manager Order Priority  \
# 0    Tina Carlton       Critical
# 1    Natasha Song         Medium
# 2    Connor Betts  Not Specified
# 3     Phoebe Gour       Critical
# 4    Tina Carlton  Not Specified
#
#                                      Product Name  ... Cost Price  \
# 0  UGen Ultra Professional Cordless Optical Suite  ...    $156.50
# 1                             Bagged Rubber Bands  ...      $0.24
# 2                 TechSavi Cordless Navigator Duo  ...     $42.11
# 3   Artisan Printable Repositionable Plastic Tabs  ...      $5.33
# 4                       Pizazz Drawing Pencil Set  ...      $1.53
#
#   Retail Price Profit Margin Order Quantity  Sub Total Discount % Discount $  \
# 0      $300.97       $144.47           23.0  $4,533.52         2%    $194.83
# 1        $1.26         $1.02            8.0     $45.20         3%      $0.00
# 2       $80.98        $38.87           45.0    $873.32         4%     $72.23
# 3        $8.60         $3.27           16.0     $73.52         1%      $4.35
# 4        $2.78         $1.25           49.0    $138.46         7%      $5.95
#
#    Order Total Shipping Cost      Total
# 0    $4,757.22         $7.18  $4,291.55
# 1       $45.90         $0.70     $46.91
# 2      $837.57         $7.18     $82.58
# 3      $740.67         $6.19    $730.92
# 4      $123.77         $1.34    $125.97
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Order No', 'Order Date', 'Customer Name', 'Address', 'City', 'State',
#        'Customer Type', 'Account Manager', 'Order Priority', 'Product Name',
#        'Product Category', 'Product Container', 'Ship Mode', 'Ship Date',
#        'Cost Price', 'Retail Price', 'Profit Margin', 'Order Quantity',
#        'Sub Total', 'Discount %', 'Discount $', 'Order Total', 'Shipping Cost',
#        'Total'],
#       dtype='object')

# %%
df = df.drop(['Order No'],axis=1)

# %%
df = df.drop(['Order Date','Customer Name','Address'],axis=1)

# %%
df['City'].nunique()
# Out:
# 2

# %% [markdown]
# ##One hot encoding using pandas

# %%
df = pd.get_dummies(df,columns=['City','State'])

# %%
df= pd.get_dummies(df,columns=['Product Container','Customer Type',])

# %%
df.columns
# Out:
# Index(['Account Manager', 'Order Priority', 'Product Name', 'Product Category',
#        'Ship Mode', 'Ship Date', 'Cost Price', 'Retail Price', 'Profit Margin',
#        'Order Quantity', 'Sub Total', 'Discount %', 'Discount $',
#        'Order Total', 'Shipping Cost', 'Total', 'City_Melbourne',
#        'City_Sydney', 'State_NSW', 'State_VIC', 'Product Container_Jumbo Drum',
#        'Product Container_Large Box', 'Product Container_Medium Box',
#        'Product Container_Small Box', 'Product Container_Small Pack',
#        'Product Container_Wrap Bag', 'Customer Type_Consumer',
#        'Customer Type_Corporate', 'Customer Type_Home Office',
#        'Customer Type_Small Business'],
#       dtype='object')

# %%
df.head()
# Out:
#   Account Manager Order Priority  \
# 0    Tina Carlton       Critical
# 1    Natasha Song         Medium
# 2    Connor Betts  Not Specified
# 3     Phoebe Gour       Critical
# 4    Tina Carlton  Not Specified
#
#                                      Product Name Product Category  \
# 0  UGen Ultra Professional Cordless Optical Suite  Office Supplies
# 1                             Bagged Rubber Bands  Office Supplies
# 2                 TechSavi Cordless Navigator Duo  Office Supplies
# 3   Artisan Printable Repositionable Plastic Tabs  Office Supplies
# 4                       Pizazz Drawing Pencil Set  Office Supplies
#
#      Ship Mode   Ship Date Cost Price Retail Price Profit Margin  \
# 0  Regular Air  04-09-2014    $156.50      $300.97       $144.47
# 1  Regular Air  26-10-2015      $0.24        $1.26         $1.02
# 2  Regular Air  13-03-2014     $42.11       $80.98        $38.87
# 3  Regular Air  20-02-2013      $5.33        $8.60         $3.27
# 4  Express Air  17-09-2014      $1.53        $2.78         $1.25
#
#    Order Quantity  ... Product Container_Jumbo Drum  \
# 0            23.0  ...                        False
# 1             8.0  ...                        False
# 2            45.0  ...                        False
# 3            16.0  ...                        False
# 4            49.0  ...                        False
#
#   Product Container_Large Box Product Container_Medium Box  \
# 0                       False                        False
# 1                       False                        False
# 2                       False                        False
# 3                       False                        False
# 4                       False                        False
#
#   Product Container_Small Box Product Container_Small Pack  \
# 0                        True                        False
# 1                       False                         True
# 2                        True                        False
# 3                       False                        False
# 4                       False                        False
#
#   Product Container_Wrap Bag  Customer Type_Consumer  Customer Type_Corporate  \
# 0                      False                   False                    False
# 1                      False                   False                     True
# 2                      False                    True                    False
# 3                       True                   False                    False
# 4                       True                   False                    False
#
#    Customer Type_Home Office  Customer Type_Small Business
# 0                      False                          True
# 1                      False                         False
# 2                      False                         False
# 3                      False                          True
# 4                      False                          True
#
# [5 rows x 30 columns]

# %%
df.drop(['Account Manager'],axis=1)
# Out:
#      Order Priority                                    Product Name  \
# 0          Critical  UGen Ultra Professional Cordless Optical Suite
# 1            Medium                             Bagged Rubber Bands
# 2     Not Specified                 TechSavi Cordless Navigator Duo
# 3          Critical   Artisan Printable Repositionable Plastic Tabs
# 4     Not Specified                       Pizazz Drawing Pencil Set
# ...             ...                                             ...
# 4995       Critical        Artisan Hi-Liter Smear-Safe Highlighters
# 4996  Not Specified            Smiths Colored Interoffice Envelopes
# 4997            Low                             Laser DVD-RAM discs
# 4998  Not Specified                              Artisan 479 Labels
# 4999            Low                                    Binder Posts
#
#      Product Category    Ship Mode   Ship Date Cost Price Retail Price  \
# 0     Office Supplies  Regular Air  04-09-2014    $156.50      $300.97
# 1     Office Supplies  Regular Air  26-10-2015      $0.24        $1.26
# 2     Office Supplies  Regular Air  13-03-2014     $42.11       $80.98
# 3     Office Supplies  Regular Air  20-02-2013      $5.33        $8.60
# 4     Office Supplies  Express Air  17-09-2014      $1.53        $2.78
# ...               ...          ...         ...        ...          ...
# 4995  Office Supplies  Regular Air  06-11-2016      $2.98        $5.84
# 4996  Office Supplies  Regular Air  18-12-2015     $19.83       $30.98
# 4997        Furniture  Regular Air  30-09-2016     $20.18       $35.41
# 4998  Office Supplies  Regular Air  20-06-2016      $1.59        $2.61
# 4999  Office Supplies  Regular Air  14-08-2015      $3.50        $5.74
#
#      Profit Margin  Order Quantity  Sub Total  ...  \
# 0          $144.47            23.0  $4,533.52  ...
# 1            $1.02             8.0     $45.20  ...
# 2           $38.87            45.0    $873.32  ...
# 3            $3.27            16.0     $73.52  ...
# 4            $1.25            49.0    $138.46  ...
# ...            ...             ...        ...  ...
# 4995         $2.86            35.0    $115.40  ...
# 4996        $11.15            49.0  $1,999.69  ...
# 4997        $15.23            19.0    $929.40  ...
# 4998         $1.02            23.0     $66.54  ...
# 4999         $2.24            31.0    $213.34  ...
#
#      Product Container_Jumbo Drum Product Container_Large Box  \
# 0                           False                       False
# 1                           False                       False
# 2                           False                       False
# 3                           False                       False
# 4                           False                       False
# ...                           ...                         ...
# 4995                        False                       False
# 4996                        False                       False
# 4997                        False                       False
# 4998                        False                       False
# 4999                        False                       False
#
#      Product Container_Medium Box Product Container_Small Box  \
# 0                           False                        True
# 1                           False                       False
# 2                           False                        True
# 3                           False                       False
# 4                           False                       False
# ...                           ...                         ...
# 4995                        False                       False
# 4996                        False                       False
# 4997                        False                       False
# 4998                        False                       False
# 4999                        False                        True
#
#      Product Container_Small Pack  Product Container_Wrap Bag  \
# 0                           False                       False
# 1                            True                       False
# 2                           False                       False
# 3                           False                        True
# 4                           False                        True
# ...                           ...                         ...
# 4995                         True                       False
# 4996                         True                       False
# 4997                         True                       False
# 4998                        False                        True
# 4999                        False                       False
#
#       Customer Type_Consumer  Customer Type_Corporate  \
# 0                      False                    False
# 1                      False                     True
# 2                       True                    False
# 3                      False                    False
# 4                      False                    False
# ...                      ...                      ...
# 4995                   False                     True
# 4996                   False                    False
# 4997                    True                    False
# 4998                   False                     True
# 4999                    True                    False
#
#       Customer Type_Home Office  Customer Type_Small Business
# 0                         False                          True
# 1                         False                         False
# 2                         False                         False
# 3                         False                          True
# 4                         False                          True
# ...                         ...                           ...
# 4995                      False                         False
# 4996                      False                          True
# 4997                      False                         False
# 4998                      False                         False
# 4999                      False                         False
#
# [5000 rows x 29 columns]

# %%
df['Ship Mode'].unique()
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
df['Order Priority'].unique()
# Out:
# array(['Critical', 'Medium', 'Not Specified', 'Low', 'High'], dtype=object)

# %% [markdown]
# ##Ordinal encoding

# %%
#ship mode and order priority need to me ordinal encoded

# %%
#train test split before ordinal encoding
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(['Profit Margin'],axis=1),df['Profit Margin'],test_size=0.2,random_state=42)

# %%
#  ship mode -> order  => express air > regular air > delivery truck
