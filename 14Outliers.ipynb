# %% [markdown]
# <a href="https://colab.research.google.com/github/arsingla786/MLFromScratch/blob/main/14Outliers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Outliers -> Unusual values in the data which might decrease model performance**

# %% [markdown]
# # **Age= 300 is an outlier ,  But oultiers are not always unwanted  ex (in anomaly detection system)**

# %% [markdown]
# How to treat -> trimming (remove) , capping (change to nearest limit value) , treat as missing value, discretization

# %% [markdown]
# how to detect ->  3 ways

# %% [markdown]
# **1. Z-Score Method**

# %% [markdown]
# **find z score -> x' = x - mue/ sigma  (should be between -3 to 3)**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
