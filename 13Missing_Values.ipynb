# %% [markdown]
# <a href="https://colab.research.google.com/github/arsingla786/MLFromScratch/blob/main/13Missing_Values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Remove  , Impute (univariate, multivariate)**

# %% [markdown]
# **Removing **
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/data_science_job.csv')

# %%
df.isnull().mean()*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
cols = [var for var in df.columns if df[var].isnull().mean()<0.05 and df[var].isnull().mean()>0]
cols
# Out:
# ['city_development_index',
#  'enrolled_university',
#  'education_level',
#  'experience',
#  'training_hours']

# %%
df[cols].sample(5)
# Out:
#        city_development_index enrolled_university education_level  experience  \
# 15010                   0.920       no_enrollment        Graduate        20.0
# 13849                   0.939    Full time course         Masters         6.0
# 12235                   0.624       no_enrollment        Graduate        18.0
# 2191                    0.920       no_enrollment        Graduate        20.0
# 15746                   0.924    Full time course     High School         3.0
#
#        training_hours
# 15010           198.0
# 13849            44.0
# 12235            25.0
# 2191            101.0
# 15746            30.0

# %% [markdown]
# #Drop these missing rows as they are very less

# %%
df_new = df[cols].dropna()

# %%
df.shape, df_new.shape
# Out:
# ((19158, 13), (17182, 5))
